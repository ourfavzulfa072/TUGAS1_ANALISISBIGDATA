# %% [markdown]
# ASSESMENT

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
base_dir = '/content/drive/MyDrive/Colab Notebooks/assessments.csv'
# !ls "/content/drive/MyDrive/Colab Notebooks/assessments.csv"
# Out:
# '/content/drive/MyDrive/Colab Notebooks/assessments.csv'

# %%
# Membaca dataset dari file CSV
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/assessments.csv')

# %%
# Menampilkan 5 baris pertama dari dataset
df.head()

# %%
# Menampilkan 5 baris terakhir dari dataset
df.tail(5)

# %%
# Melihat informasi dasar tentang dataset
print(df.info())

# %%
# Melihat jumlah missing values pada setiap kolom
print("\nJumlah Missing Values pada Setiap Kolom:")
print(df.isnull().sum())

# %%
# Statistik deskriptif untuk kolom numerik
df.describe()

# %%
# Visualisasi distribusi data untuk kolom 'weight'
plt.figure(figsize=(10, 6))
sns.histplot(df['weight'], bins=10, kde=True)
plt.title('Distribusi Weight')
plt.xlabel('Weight')
plt.ylabel('Count')
plt.show()

# %%
# Visualisasi hubungan antara 'assessment_type' dan 'weight'
plt.figure(figsize=(8, 6))
sns.boxplot(x='assessment_type', y='weight', data=df)
plt.title('Hubungan Assessment Type dan Weight')
plt.xlabel('Assessment Type')
plt.ylabel('Weight')
plt.show()

# %%
# Visualisasi hubungan antara 'code_module' dan 'weight'
plt.figure(figsize=(12, 6))
sns.boxplot(x='code_module', y='weight', data=df)
plt.title('Hubungan Code Module dan Weight')
plt.xlabel('Code Module')
plt.ylabel('Weight')
plt.show()

# %%
# Menampilkan jumlah missing values pada setiap kolom
missing_data = df.isnull().sum()

# Menampilkan kolom-kolom dengan missing values (jika ada)
columns_with_missing_data = missing_data[missing_data > 0]
print("Kolom dengan Missing Values:")
print(columns_with_missing_data)

# Menampilkan jumlah total missing values dalam dataset
total_missing_values = missing_data.sum()
print("\nTotal Missing Values dalam Dataset:", total_missing_values)

# %%
#Mencari data date yang hilang pada rentang waktu tertentu
df['date'] = df['date'].interpolate(method='linear')

df

# %% [markdown]
# -

# %% [markdown]
# COURSES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Load Dataset
#data = pd.read_csv("courses.csv")

# %%
base_dir = '/content/drive/MyDrive/Colab Notebooks/courses.csv'
# !ls "/content/drive/MyDrive/Colab Notebooks/courses.csv"
# Out:
# '/content/drive/MyDrive/Colab Notebooks/courses.csv'

# %%
# Membaca dataset dari file CSV
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/courses.csv')

# %%
# Menampilkan 5 baris pertama dari dataset
df.head()
# Out:
#   code_module code_presentation  module_presentation_length
# 0         AAA             2013J                         268
# 1         AAA             2014J                         269
# 2         BBB             2013J                         268
# 3         BBB             2014J                         262
# 4         BBB             2013B                         240

# %%
# Menampilkan 5 baris terakhir dari dataset
df.tail(5)
# Out:
#    code_module code_presentation  module_presentation_length
# 17         FFF             2013B                         240
# 18         FFF             2014B                         241
# 19         GGG             2013J                         261
# 20         GGG             2014J                         269
# 21         GGG             2014B                         241

# %%
# Melihat informasi dasar tentang dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   code_module                 22 non-null     object
#  1   code_presentation           22 non-null     object
#  2   module_presentation_length  22 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 656.0+ bytes
# None

# %%
# Melihat jumlah missing values pada setiap kolom
print("\nJumlah Missing Values pada Setiap Kolom:")
print(df.isnull().sum())
# Out:
# Jumlah Missing Values pada Setiap Kolom:
# code_module                   0
# code_presentation             0
# module_presentation_length    0
# dtype: int64

# %%
# Statistik deskriptif untuk kolom numerik
df.describe()
# Out:
#        module_presentation_length
# count                   22.000000
# mean                   255.545455
# std                     13.654677
# min                    234.000000
# 25%                    241.000000
# 50%                    261.500000
# 75%                    268.000000
# max                    269.000000

# %%
# Melihat jumlah missing values pada setiap kolom
print("\nJumlah Missing Values pada Setiap Kolom:")
print(df.isnull().sum())
# Out:
# Jumlah Missing Values pada Setiap Kolom:
# code_module                   0
# code_presentation             0
# module_presentation_length    0
# dtype: int64

# %%
grouped_stats = df.groupby('code_module')['module_presentation_length'].describe() #Gabungkan code_module dengan module_presentation_length
print("Statistik Deskriptif Berdasarkan Kelompok Code Module:\n", grouped_stats)
# Out:
# Statistik Deskriptif Berdasarkan Kelompok Code Module:
#               count        mean        std    min     25%    50%     75%    max
# code_module
# AAA            2.0  268.500000   0.707107  268.0  268.25  268.5  268.75  269.0
# BBB            4.0  251.000000  16.532796  234.0  238.50  251.0  263.50  268.0
# CCC            2.0  255.000000  19.798990  241.0  248.00  255.0  262.00  269.0
# DDD            4.0  251.000000  12.138094  240.0  240.75  251.0  261.25  262.0
# EEE            3.0  259.333333  15.885003  241.0  254.50  268.0  268.50  269.0
# FFF            4.0  254.500000  16.176114  240.0  240.75  254.5  268.25  269.0
# GGG            3.0  257.000000  14.422205  241.0  251.00  261.0  265.00  269.0

# %%
data_count = df.groupby(['code_module', 'code_presentation']).size().reset_index(name='count')
print("Jumlah Data per Code Module dan Code Presentation:\n", data_count)
# Out:
# Jumlah Data per Code Module dan Code Presentation:
#     code_module code_presentation  count
# 0          AAA             2013J      1
# 1          AAA             2014J      1
# 2          BBB             2013B      1
# 3          BBB             2013J      1
# 4          BBB             2014B      1
# 5          BBB             2014J      1
# 6          CCC             2014B      1
# 7          CCC             2014J      1
# 8          DDD             2013B      1
# 9          DDD             2013J      1
# 10         DDD             2014B      1
# 11         DDD             2014J      1
# 12         EEE             2013J      1
# 13         EEE             2014B      1
# 14         EEE             2014J      1
# 15         FFF             2013B      1
# 16         FFF             2013J      1
# 17         FFF             2014B      1
# 18         FFF             2014J      1
# 19         GGG             2013J      1
# 20         GGG             2014B      1
# ...

# %%
#Melakukan Plotting menggunakan diagram batang
plt.figure(figsize=(8, 6))
sns.histplot(df['module_presentation_length'], bins=10, kde=True)
plt.xlabel('Module Presentation Length')
plt.ylabel('Frequency')
plt.title('Distribution of Module Presentation Length')
plt.show()

# %%
#Melakukan plotting menggunakan box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='code_module', y='module_presentation_length', data=df)
plt.xlabel('Code Module')
plt.ylabel('Module Presentation Length')
plt.title('Module Presentation Length by Code Module')
plt.xticks(rotation=45)
plt.show()

# %%
#Melakukan plotting menggunakan scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='code_module', y='code_presentation', data=df, hue='module_presentation_length')
plt.xlabel('Code Module')
plt.ylabel('Code Presentation')
plt.title('Scatter Plot of Code Module and Code Presentation')
plt.xticks(rotation=45)
plt.show()

# %%
#Melakukan plotting data code_module menggunakan histrogram
plt.figure(figsize=(10, 6))
sns.countplot(x='code_module', data=df)
plt.xlabel('Code Module')
plt.ylabel('Count')
plt.title('Count of Data per Code Module')
plt.xticks(rotation=45)
plt.show()

# %%
#Melakukan plotting code_presentation menggunakan histogram
plt.figure(figsize=(10, 6))
sns.countplot(x='code_presentation', data=df)
plt.xlabel('Code Presentation')
plt.ylabel('Count')
plt.title('Count of Data per Code Presentation')
plt.xticks(rotation=45)
plt.show()

# %%
print("Jumlah unik code_module:", df['code_module'].nunique())
print("Jumlah unik code_presentation:", df['code_presentation'].nunique())

# %% [markdown]
# -

# %% [markdown]
# STUDENT ASSESSMENTS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_dir = '/content/drive/MyDrive/Colab Notebooks/dataset/studentAssessment.csv'
# !ls "/content/drive/MyDrive/Colab Notebooks/dataset/studentAssessment.csv"
# Out:
# '/content/drive/MyDrive/Colab Notebooks/dataset/studentAssessment.csv'

# %%
# Membaca dataset dari file CSV
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/studentAssessment.csv')

# %%
# Menampilkan 5 baris terakhir dari dataset
df.tail(5)
# Out:
#         id_assessment  id_student  date_submitted  is_banked  score
# 173907          37443      527538             227          0   60.0
# 173908          37443      534672             229          0  100.0
# 173909          37443      546286             215          0   80.0
# 173910          37443      546724             230          0  100.0
# 173911          37443      558486             224          0   80.0

# %%
# Menampilkan detail tentang dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173912 entries, 0 to 173911
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id_assessment   173912 non-null  int64
#  1   id_student      173912 non-null  int64
#  2   date_submitted  173912 non-null  int64
#  3   is_banked       173912 non-null  int64
#  4   score           173739 non-null  float64
# dtypes: float64(1), int64(4)
# memory usage: 6.6 MB

# %%
# Menampilkan statistik deskriptif
df.describe()
# Out:
#        id_assessment    id_student  date_submitted      is_banked  \
# count  173912.000000  1.739120e+05   173912.000000  173912.000000
# mean    26553.803556  7.051507e+05      116.032942       0.010977
# std      8829.784254  5.523952e+05       71.484148       0.104194
# min      1752.000000  6.516000e+03      -11.000000       0.000000
# 25%     15022.000000  5.044290e+05       51.000000       0.000000
# 50%     25359.000000  5.852080e+05      116.000000       0.000000
# 75%     34883.000000  6.344980e+05      173.000000       0.000000
# max     37443.000000  2.698588e+06      608.000000       1.000000
#
#                score
# count  173739.000000
# mean       75.799573
# std        18.798107
# min         0.000000
# 25%        65.000000
# 50%        80.000000
# 75%        90.000000
# max       100.000000

# %%
# Cek missing value
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# id_assessment       0
# id_student          0
# date_submitted      0
# is_banked           0
# score             173
# dtype: int64

# %%
# Menghapus baris dengan missing value
df.dropna(inplace=True)

# %%
print(df.columns)
# Out:
# Index(['id_assessment', 'id_student', 'date_submitted', 'is_banked', 'score'], dtype='object')

# %%
#Melakukan Plotting menggunakan diagram batang
plt.figure(figsize=(8, 6))
sns.histplot(df['score'], kde=True, bins=10)
plt.title('Distribusi Skor')
plt.xlabel('Skor')
plt.ylabel('Frekuensi')
plt.show()

# %%
# menampilkan hasil korelasi antar fitur yang ada dalam dataset
correlation_matrix = df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Korelasi antara Kolom')
plt.show()

# %%
#Melakukan plotting menggunakan box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x='is_banked', y='score', data=df)
plt.title('Boxplot Skor berdasarkan is_banked')
plt.xlabel('is_banked')
plt.ylabel('Skor')
plt.show()

# %%
# menampilkan data plotting menggunakan histogram
plt.figure(figsize=(16, 12))
sns.countplot(x='id_assessment', data=df)
plt.title('Jumlah Pengumpulan berdasarkan id_assessment')
plt.xlabel('id_assessment')
plt.ylabel('Jumlah Pengumpulan')
plt.xticks(rotation=90)
plt.show()

# %%
#Melakukan plotting menggunakan scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='date_submitted', y='score', data=df)
plt.title('Hubungan antara date_submitted dan Skor')
plt.xlabel('date_submitted')
plt.ylabel('Skor')
plt.show()

# %% [markdown]
# -

# %% [markdown]
# STUDENT INFO

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
base_dir = '/content/drive/MyDrive/Colab Notebooks/studentInfo.csv'
# !ls "/content/drive/MyDrive/Colab Notebooks/studentInfo.csv"
# Out:
# '/content/drive/MyDrive/Colab Notebooks/studentInfo.csv'

# %%
# Membaca dataset dari file CSV
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/studentInfo.csv')

# %%
# Menampilkan 5 baris terakhir dari dataset
df.tail(5)
# Out:
#       code_module code_presentation  id_student gender               region  \
# 32588         GGG             2014J     2640965      F                Wales
# 32589         GGG             2014J     2645731      F  East Anglian Region
# 32590         GGG             2014J     2648187      F         South Region
# 32591         GGG             2014J     2679821      F    South East Region
# 32592         GGG             2014J     2684003      F     Yorkshire Region
#
#            highest_education imd_band age_band  num_of_prev_attempts  \
# 32588     Lower Than A Level    10-20     0-35                     0
# 32589     Lower Than A Level   40-50%    35-55                     0
# 32590  A Level or Equivalent   20-30%     0-35                     0
# 32591     Lower Than A Level  90-100%    35-55                     0
# 32592       HE Qualification   50-60%    35-55                     0
#
#        studied_credits disability final_result
# ...

# %%
# Menampilkan detail tentang dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code_module           32593 non-null  object
#  1   code_presentation     32593 non-null  object
#  2   id_student            32593 non-null  int64
#  3   gender                32593 non-null  object
#  4   region                32593 non-null  object
#  5   highest_education     32593 non-null  object
#  6   imd_band              31482 non-null  object
#  7   age_band              32593 non-null  object
#  8   num_of_prev_attempts  32593 non-null  int64
#  9   studied_credits       32593 non-null  int64
#  10  disability            32593 non-null  object
#  11  final_result          32593 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 3.0+ MB

# %%
# Menampilkan statistik deskriptif
df.describe()
# Out:
#          id_student  num_of_prev_attempts  studied_credits
# count  3.259300e+04          32593.000000     32593.000000
# mean   7.066877e+05              0.163225        79.758691
# std    5.491673e+05              0.479758        41.071900
# min    3.733000e+03              0.000000        30.000000
# 25%    5.085730e+05              0.000000        60.000000
# 50%    5.903100e+05              0.000000        60.000000
# 75%    6.444530e+05              0.000000       120.000000
# max    2.716795e+06              6.000000       655.000000

# %%
# Periksa apakah ada missing value
print(df.isnull().sum())
# Out:
# code_module                0
# code_presentation          0
# id_student                 0
# gender                     0
# region                     0
# highest_education          0
# imd_band                1111
# age_band                   0
# num_of_prev_attempts       0
# studied_credits            0
# disability                 0
# final_result               0
# dtype: int64

# %%
df['imd_band'].fillna(0, inplace=True)

# %%
# Melakukan plotting gender
sns.countplot(x='gender', data=df)
plt.title('Distribusi Gender')
plt.show()

# %%
# Melakukan plotting fitur final_result menggunakan histogram
sns.countplot(x='final_result', data=df)
plt.title('Distribusi Hasil Akhir')
plt.show()

# %%
# Melakukan plotting fitur age_band menggunakan histogram
sns.histplot(df['age_band'], bins=5)
plt.title('Distribusi Usia')
plt.xlabel('Kelompok Usia')
plt.ylabel('Jumlah')
plt.show()

# %%
# menampilkan hasil korelasi antar fitur yang ada dalam dataset
kolom_numerik = df.select_dtypes(include=['int64', 'float64']).columns
matriks_korelasi = df[kolom_numerik].corr()
sns.heatmap(matriks_korelasi, annot=True, cmap='coolwarm')
plt.title('Heatmap Korelasi')
plt.show()

# %%
#Melakukan plotting menggunakan box plot
sns.boxplot(x='final_result', y='studied_credits', data=df)
plt.title('Hubungan Hasil Akhir dan Studied Credits')
plt.show()

# %%
# Melakukan plotting fitur region
sns.countplot(x='region', data=df)
plt.title('Distribusi Region')
plt.xticks(rotation=90)
plt.show()

# %%
# Menghitung isi fitur gender
gender_counts = df['gender'].value_counts()
print(gender_counts)
# Out:
# M    17875
# F    14718
# Name: gender, dtype: int64

# %%
# Melakukan plotting untuk melihat perbandingan gender
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')
plt.title('Perbandingan Gender')
plt.show()

# %%
# menghitung isi fitur region
region_counts = df['region'].value_counts()
print(region_counts.head())
# Out:
# Scotland                3446
# East Anglian Region     3340
# London Region           3216
# South Region            3092
# North Western Region    2906
# Name: region, dtype: int64

# %%
# Melakukan plotting fitur region
plt.figure(figsize=(12, 6))
sns.countplot(x='region', data=df, order=df['region'].value_counts().index)
plt.title('Distribusi Region')
plt.xticks(rotation=90)
plt.show()

# %%
# menghitung isi fitur highest_education
highest_education_counts = df['highest_education'].value_counts()
print(highest_education_counts)
# Out:
# A Level or Equivalent          14045
# Lower Than A Level             13158
# HE Qualification                4730
# No Formal quals                  347
# Post Graduate Qualification      313
# Name: highest_education, dtype: int64

# %%
# Melakukan plotting untuk fitur highest_education
plt.figure(figsize=(8, 6))
sns.countplot(x='highest_education', data=df, order=df['highest_education'].value_counts().index)
plt.title('Distribusi Tingkat Pendidikan Tertinggi')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# -

# %% [markdown]
# STUDENT REGISTRATION

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
base_dir = '/content/drive/MyDrive/Colab Notebooks/studentRegistration.csv'
# !ls "/content/drive/MyDrive/Colab Notebooks/studentRegistration.csv"
# Out:
# '/content/drive/MyDrive/Colab Notebooks/studentRegistration.csv'

# %%
# Membaca dataset dari file CSV
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/studentRegistration.csv')

# %%
# Menampilkan 5 baris pertama dari dataset
df.head(5)
# Out:
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       11391             -159.0
# 1         AAA             2013J       28400              -53.0
# 2         AAA             2013J       30268              -92.0
# 3         AAA             2013J       31604              -52.0
# 4         AAA             2013J       32885             -176.0
#
#    date_unregistration
# 0                  NaN
# 1                  NaN
# 2                 12.0
# 3                  NaN
# 4                  NaN

# %%
# Menampilkan 5 baris pertama dari dataset
df.head(5)
# Out:
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       11391             -159.0
# 1         AAA             2013J       28400              -53.0
# 2         AAA             2013J       30268              -92.0
# 3         AAA             2013J       31604              -52.0
# 4         AAA             2013J       32885             -176.0
#
#    date_unregistration
# 0                  NaN
# 1                  NaN
# 2                 12.0
# 3                  NaN
# 4                  NaN

# %%
# Menampilkan 5 baris terakhir dari dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   code_module          32593 non-null  object
#  1   code_presentation    32593 non-null  object
#  2   id_student           32593 non-null  int64
#  3   date_registration    32548 non-null  float64
#  4   date_unregistration  10072 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.2+ MB

# %%
# Statistik deskriptif
df.describe()
# Out:
#          id_student  date_registration  date_unregistration
# count  3.259300e+04       32548.000000         10072.000000
# mean   7.066877e+05         -69.411300            49.757645
# std    5.491673e+05          49.260522            82.460890
# min    3.733000e+03        -322.000000          -365.000000
# 25%    5.085730e+05        -100.000000            -2.000000
# 50%    5.903100e+05         -57.000000            27.000000
# 75%    6.444530e+05         -29.000000           109.000000
# max    2.716795e+06         167.000000           444.000000

# %%
# Menghitung jumlah nilai yang hilang
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# code_module                0
# code_presentation          0
# id_student                 0
# date_registration         45
# date_unregistration    22521
# dtype: int64

# %%
# Mengganti nilai yang hilang dengan rata-rata kolom date_registration
mean_date_registration = df['date_registration'].mean()
df['date_registration'].fillna(mean_date_registration, inplace=True)

# Mengganti nilai yang hilang dengan median kolom date_unregistration
median_date_unregistration = df['date_unregistration'].median()
df['date_unregistration'].fillna(median_date_unregistration, inplace=True)

# %%
# Melakukan plotting data_registration menggunakan histogram
plt.figure(figsize=(8, 6))
sns.histplot(df['date_registration'], bins=30, kde=True)
plt.xlabel('Date Registration')
plt.ylabel('Frequency')
plt.title('Distribution of Date Registration')
plt.show()

# %%
# melakukan plotting date_registration dan date_unregistration menggunakan scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df['date_registration'], df['date_unregistration'], alpha=0.5)
plt.xlabel('Date Registration')
plt.ylabel('Date Unregistration')
plt.title('Scatter Plot between Date Registration and Date Unregistration')
plt.grid(True)
plt.show()

# %%
# Plotting date_registration menggunakan hisplot
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['date_registration'], bins=30, kde=True)
plt.xlabel('Date Registration')
plt.ylabel('Frequency')
plt.title('Distribution of Date Registration')

# Plotting date_unregistration
plt.subplot(1, 2, 2)
sns.histplot(df['date_unregistration'], bins=30, kde=True)
plt.xlabel('Date Unregistration')
plt.ylabel('Frequency')
plt.title('Distribution of Date Unregistration')

plt.tight_layout()
plt.show()

# %%
# melakukan visualisasi menggunakan boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['date_registration', 'date_unregistration']], orient='vertical')
plt.ylabel('Date')
plt.title('Box Plot of Date Registration and Date Unregistration')
plt.show()

# %% [markdown]
# -

# %% [markdown]
# STUDENT VLE

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
base_dir = '/content/drive/MyDrive/Colab Notebooks/studentVle.csv'
# !ls "/content/drive/MyDrive/Colab Notebooks/studentVle.csv"
# Out:
# '/content/drive/MyDrive/Colab Notebooks/studentVle.csv'

# %%
# Membaca dataset dari file CSV
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/studentVle.csv')

# %%
# Menampilkan informasi dasar tentang dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10655280 entries, 0 to 10655279
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   code_module        object
#  1   code_presentation  object
#  2   id_student         int64
#  3   id_site            int64
#  4   date               int64
#  5   sum_click          int64
# dtypes: int64(4), object(2)
# memory usage: 487.8+ MB

# %%
# Menampilkan 5 baris pertama data
df.head(5)
# Out:
#   code_module code_presentation  id_student  id_site  date  sum_click
# 0         AAA             2013J       28400   546652   -10          4
# 1         AAA             2013J       28400   546652   -10          1
# 2         AAA             2013J       28400   546652   -10          1
# 3         AAA             2013J       28400   546614   -10         11
# 4         AAA             2013J       28400   546714   -10          1

# %%
# Menampilkan 5 baris pertama data
df.tail(5)
# Out:
#          code_module code_presentation  id_student  id_site  date  sum_click
# 10655275         GGG             2014J      675811   896943   269          3
# 10655276         GGG             2014J      675578   896943   269          1
# 10655277         GGG             2014J      654064   896943   269          3
# 10655278         GGG             2014J      654064   896939   269          1
# 10655279         GGG             2014J      654064   896939   269          1

# %%
# Statistik deskriptif untuk kolom numerik
df.describe()
# Out:
#          id_student       id_site          date     sum_click
# count  1.065528e+07  1.065528e+07  1.065528e+07  1.065528e+07
# mean   7.333336e+05  7.383234e+05  9.517400e+01  3.716946e+00
# std    5.827060e+05  1.312196e+05  7.607130e+01  8.849047e+00
# min    6.516000e+03  5.267210e+05 -2.500000e+01  1.000000e+00
# 25%    5.077430e+05  6.735190e+05  2.500000e+01  1.000000e+00
# 50%    5.882360e+05  7.300690e+05  8.600000e+01  2.000000e+00
# 75%    6.464840e+05  8.770300e+05  1.560000e+02  3.000000e+00
# max    2.698588e+06  1.049562e+06  2.690000e+02  6.977000e+03

# %%
# Menghitung jumlah nilai yang hilang
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# code_module          0
# code_presentation    0
# id_student           0
# id_site              0
# date                 0
# sum_click            0
# dtype: int64

# %%
# Visualisasi distribusi kolom "sum_click"
plt.figure(figsize=(8, 4))
sns.histplot(data=df, x="sum_click", bins=20, kde=True)
plt.title("Distribusi sum_click")
plt.xlabel("sum_click")
plt.ylabel("Frekuensi")
plt.show()

# %%
# Visualisasi hubungan antara "sum_click" dan "date" menggunakan scatterplot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="date", y="sum_click")
plt.title("Hubungan antara date dan sum_click")
plt.xlabel("date")
plt.ylabel("sum_click")
plt.show()

# %%
# Visualisasi hubungan antara "id_site" dan "sum_click" menggunakan scatterplot
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x="id_site", y="sum_click")
plt.title("Hubungan antara id_site dan sum_click")
plt.xlabel("id_site")
plt.ylabel("sum_click")
plt.show()

# %%
# Visualisasi hubungan antara "sum_click" dan "code_module" menggunakan boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x="code_module", y="sum_click")
plt.title("Hubungan antara code_module dan sum_click")
plt.xlabel("code_module")
plt.ylabel("sum_click")
plt.show()

# %%
# Visualisasi hubungan antara "code_presentation" dan "sum_click" menggunakan boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x="code_presentation", y="sum_click")
plt.title("Distribusi sum_click per code_presentation")
plt.xlabel("code_presentation")
plt.ylabel("sum_click")
plt.xticks(rotation=45)
plt.show()

# %%
# menampilkan hasil korelasi antar fitur yang ada dalam dataset
pivot_table = df.pivot_table(values="sum_click", index="code_module", columns="code_presentation")
plt.figure(figsize=(12, 6))
sns.heatmap(pivot_table, cmap="YlGnBu", annot=True, fmt=".1f")
plt.title("Distribusi sum_click per code_module dan code_presentation")
plt.xlabel("code_presentation")
plt.ylabel("code_module")
plt.show()

# %% [markdown]
# -

# %% [markdown]
# VLE

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
base_dir = '/content/drive/MyDrive/Colab Notebooks/vle.csv'
# !ls "/content/drive/MyDrive/Colab Notebooks/vle.csv"
# Out:
# '/content/drive/MyDrive/Colab Notebooks/vle.csv'

# %%
# Membaca dataset dari file CSV
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vle.csv')

# %%
# Menampilkan 5 baris pertama dari dataset
df.head(5)
# Out:
#    id_site code_module code_presentation activity_type  week_from  week_to
# 0   546943         AAA             2013J      resource        NaN      NaN
# 1   546712         AAA             2013J     oucontent        NaN      NaN
# 2   546998         AAA             2013J      resource        NaN      NaN
# 3   546888         AAA             2013J           url        NaN      NaN
# 4   547035         AAA             2013J      resource        NaN      NaN

# %%
# Menampilkan 5 baris terakhir dari dataset
df.tail(5)
# Out:
#       id_site code_module code_presentation activity_type  week_from  week_to
# 6359   897063         GGG             2014J      resource        NaN      NaN
# 6360   897109         GGG             2014J      resource        NaN      NaN
# 6361   896965         GGG             2014J     oucontent        NaN      NaN
# 6362   897060         GGG             2014J      resource        NaN      NaN
# 6363   897100         GGG             2014J      resource        NaN      NaN

# %%
# Menampilkan Informasi tentang dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6364 entries, 0 to 6363
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_site            6364 non-null   int64
#  1   code_module        6364 non-null   object
#  2   code_presentation  6364 non-null   object
#  3   activity_type      6364 non-null   object
#  4   week_from          1121 non-null   float64
#  5   week_to            1121 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 298.4+ KB
# None

# %%
# Statistik deskriptif untuk kolom kategorikal
df.describe(include='object')
# Out:
#        code_module code_presentation activity_type
# count         6364              6364          6364
# unique           7                 4            20
# top            FFF             2013J      resource
# freq          1967              1772          2660

# %%
# Periksa data yang hilang
missing_data = df.isnull().sum()
print(missing_data)
# Out:
# id_site                 0
# code_module             0
# code_presentation       0
# activity_type           0
# week_from            5243
# week_to              5243
# dtype: int64

# %%
# Menghapus baris dengan nilai yang hilang
data = df.dropna()

# %%
# Mengganti nilai yang hilang dengan rata-rata kolom
data['week_from'].fillna(data['week_from'].mean(), inplace=True)
data['week_to'].fillna(data['week_to'].mean(), inplace=True)
# Out:
# <ipython-input-89-f56140f50682>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['week_from'].fillna(data['week_from'].mean(), inplace=True)
# <ipython-input-89-f56140f50682>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['week_to'].fillna(data['week_to'].mean(), inplace=True)

# %%
# Plot jumlah aktivitas berdasarkan jenis aktivitas menggunakan histogram
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='activity_type')
plt.title('Jumlah Aktivitas berdasarkan Jenis Aktivitas')
plt.xticks(rotation=45)
plt.show()

# %%
# Melakukan plotting fitur code_module menggunakan histogram
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='code_module')
plt.title('Distribusi Jenis Modul Kode')
plt.xticks(rotation=45)
plt.show()

# %%
# Melakukan plotting fitur code_presentation menggunakan histogram
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='code_presentation')
plt.title('Distribusi Jenis Presentasi Kode')
plt.xticks(rotation=45)
plt.show()

# %%
# Melakukan plotting code_modul menggunakan countplot
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='code_module', hue='activity_type')
plt.title('Distribusi Jenis Aktivitas berdasarkan Modul Kode')
plt.xticks(rotation=45)
plt.legend(title='Aktivitas', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# Konversi kolom "week_from" dan "week_to" menjadi tipe data numerik (jika belum)
data['week_from'] = pd.to_numeric(data['week_from'], errors='coerce')
data['week_to'] = pd.to_numeric(data['week_to'], errors='coerce')

# Visualisasi distribusi "week_from"
plt.figure(figsize=(10, 6))
plt.hist(data['week_from'].dropna(), bins=20, color='skyblue', edgecolor='black')
plt.title('Distribusi "week_from"')
plt.xlabel('Minggu')
plt.ylabel('Jumlah')
plt.grid(True)
plt.show()

# Visualisasi distribusi "week_to"
plt.figure(figsize=(10, 6))
plt.hist(data['week_to'].dropna(), bins=20, color='salmon', edgecolor='black')
plt.title('Distribusi "week_to"')
plt.xlabel('Minggu')
plt.ylabel('Jumlah')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-94-74bcf60a3db7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['week_from'] = pd.to_numeric(data['week_from'], errors='coerce')
# <ipython-input-94-74bcf60a3db7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['week_to'] = pd.to_numeric(data['week_to'], errors='coerce')
